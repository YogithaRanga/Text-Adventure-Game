# %% [markdown]
# Source to the Survivor game show:
# https://en.wikipedia.org/wiki/Survivor_(American_TV_series)
#
# Sharing below a flow chart of the modified version of the Survivor show as 'SURVIVOR ADVENTURE TEXT GAME".The modified game will not be a team game rather will be a single player game.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Survivor Game Updated as below:-
#
# Code Cells and Comments
# - All comments are left aligned
#
# User Input and Conditional Statements
# - Prompt updated in all inputs
# - . lower function updated in Stage 3 - Water section for both blue and red bands
# - . upper function updated in stage 2 and Finale functions
#
# Replay Value
# - Random choice method used in Stage 1 and Finale functions to improve game's replay value
#
# Bugs/Errors
# - Casefold function updated in Stage 3 - Fire and Water sections for both blue and red bands and   also in Stage 4

# %%
# Importing necessary packages
import sys
import warnings
import random as rand 
# To ignore the sys.exit warning message when we exit the program from the middle
warnings.filterwarnings('ignore')

#-----------------------------------------------------------------------------

# Multiplying * into 96 times to print as follows *********-------------------
print(f"""{96*"*"}\n""")

# Virtual Survivor text game season 1 header----------------------------------
print("                        VIRTUAL SURVIVOR ADVENTURE TEXT GAME SEASON 1\n")

# Multiplying * into 96 times to print as follows *********-------------------
print(f"""{96*"*"}\n""")

#-----------------------------------------------------------------------------


# Virtual survivor text game introduction-------------------------------------
print("""This game features contestants deliberately marooned in an isolated 
location, where they must provide food, water, fire, and shelter for themselves. 
They compete in challenges for rewards and immunity from elimination. 
They are progressively eliminated from the game based on the performance.
This game challenges the mental abilities and the contestant who survives all the 
stages will be declared as the title winner.\n""")

# Various stages in the game--------------------------------------------------
print("""This game has been split into 6 stages as follow:
1. Contestants will be provided either 'Red' or 'Blue' band. 
2. Based on the band contestants will be allocated to resourceful and 
   resourseless part of the island.
3. Contestants need to lookout for food, water, fire, and shelter in the
   respective islands.
4. Reward task will help skip stage 5.
5. Elimination challenge.
6. Finale.\n""")
print("\n")

#-----------------------------------------------------------------------------
# NOTE: Kindly go all the way down to start from the main function
#-----------------------------------------------------------------------------


#*****************************************************************************
# Stage 1-To decide the band colour
#*****************************************************************************
def stage1():
# Heads up on the band colours
    print(f"""{45*"*"}STAGE 1{44*"*"}\n""")
    print("Let's get started.")  
    print("""We have two bands 1.The blue band called 'Sele'. 
                  2.The red band called 'Dakal'.""")
    print("\n")
    print("""To join one of the two bands you will have to answer a question. 
If you answer correctly you will be put under the blue band else red band.\n""")
    
# To validate if user is providing the correct input format 
# Input value to be numeric and should be in [1,2,3]
    lst1=[1,2,3]
    Numeric = False
# Loop until user provides the right input format       
    while Numeric == False:
        try:
# Question to decide the band colour
# Using random function to prompt different question each time the player plays the game
            Q1 = """Which is the largest island amongst the following?
1.England
2.Japan
3.New Guinea\n>> """ 
            Q2 = """Baffin Island is located in which country:
1.Canada
2.United States
3.Belarus\n>>"""
            Q3 = """Hawaiian islands are located in:
1.North Atlantic Ocean
2.North Pacific Ocean
3.South Atlantic Ocean\n>>""" 
            Team_map_rand_ques_list = [Q1,Q2,Q3]
# Using random.choice function to randomly prompt one of the three questions            
            Team_map_rand_ques = rand.choice(Team_map_rand_ques_list) 
            Team_map_Q1 = input(prompt= Team_map_rand_ques )                               
# Converting input to integer in order to validate the provided input    
            Team_map_Q1 = int(Team_map_Q1)
            if Team_map_Q1 in lst1:
                Numeric = True  
# If the value provided is not in the lst1 the following message will be displayed                
            else:
                print("Please provide a correct value.(e.g., 1 or 2 or 3)")
# If the value provided is not an interger the following message will be displayed              
        except:
            print("Please provide a numeric value.\n")      

# Verifying if the given input is the right answer            
    if (Team_map_rand_ques == Q1 and Team_map_Q1 == 3) or ((Team_map_rand_ques == Q2 and Team_map_Q1 == 1) or (Team_map_rand_ques == Q3 and Team_map_Q1 == 2)):
# Blue band flow  
        print("""You are right! You belong to the Blue band 'Sele' and you have an  
advantage which will be revealed as the game progresses.""")
# Calling Stage 2 function-To decide between resourceful island and resourseless island
        print("\n")
        stage2()  
# Calling Stage 3 function-Contestants need to lookout for food, water, fire, and shelter
# Stage 3 questions vary based on the band colour
        print("\n")
        stage3_blue() 
       
    else:
# Red band flow            
        print("You belong to the Red band 'Dakal'.") 
        if Team_map_rand_ques == Q1:
            print("The right answer is option '3.New Guinea'.") 
        elif Team_map_rand_ques == Q2:
            print("The right answer is option '1.Canada'.")  
        else:
            print("The right answer is option '2.North Pacific Ocean'.")              
# Calling Stage 2 function-To decide between resourceful island and resourseless island
        print("\n")
        stage2()      
# Calling Stage 3 function-Contestants need to lookout for food, water, fire, and shelter
        print("\n")
# Stage 3 questions vary based on the band colour    
        stage3_red()   
# Brings us back to the main function    
    return ()


#*****************************************************************************
# Stage 2-To decide between resourceful island and resourseless island
#*****************************************************************************
def stage2():
# Details about the island they will be staying  
    print(f"""{45*"*"}STAGE 2{44*"*"}\n""")   
    
# To print the below information in Caps using upper function   

    print("""Contestants belonging to 'Sele'(Blue band) will have an advantage, 
you will stay in the part of the island where you will have abundant resources.\n""". upper())  
    
    print("""Contestants belonging to 'Dakal'(Red band) will stay in the part of 
the island where you will have minimal resources.\n""".upper())   
    
    input(prompt ='<Press any key to proceed to the respective islands>\n')

# Control returns back to the calling program which is the stage1

#*****************************************************************************
# Stage 3-BLUE-Band need to lookout for food, water, fire, and shelter
#*****************************************************************************
def stage3_blue():
# Heads up    
    print(f"""{43*"*"}STAGE 3- BLUE{41*"*"}\n""")  
    print("""You have landed in the part of the island with abundant resources 
as you belong to the blue band. Here, you will have to lookout for food, water, fire 
and shelter.""")
    
# Build fire------------------------------------------------------------------   
    print(f"""{44*"-"}BUILD FIRE{44*"-"}\n""") 
    print("""Firstly, you need to build fire to cook and for warmth. In order to 
build fire you need to answer a riddle.\n""")
# Question to earn fire    
    riddle = input(prompt = """What goes up and down but doesn't move?\n>> """)  
    print("\n")
# casefold function used for caseless matching    
    riddle = riddle.casefold()
# Validating user input in the list value    
    if (riddle == "staircase") or (riddle == "stairs"):
        print("You are right! You will receive all the necessary equipments to build fire.")
    else:
        print("Sorry incorrect answer, you will not be able to build fire.")  
        print(f"The right answer is 'staircase'.")        
# To print space        
    print("\n")

    
# Construct shelter-----------------------------------------------------------   
# Heads up
    print(f"""{42*"-"}CONSTRUCT SHELTER{37*"-"}\n""")    
    print("""Secondly, you will have to construct shelter. For that you will have to answer 
a question related to shelter.""")
    
# Initializing value to validate if user is providing the correct input format 
# Input value to be numeric and should be in [1,2,3]

    lst2 = [1,2,3]
    correct_value = False
# Loop until user provides the right input format    
    while correct_value == False:
        try:            
# Question to earn shelter     
            Construct_shelter_Q1 = input(prompt= """Where are bamboo and wooden houses found?
1.Plains
2.Earthquake prone areas
3.Caves\n>> """)  
# Converting input to integer in order to validate the provided input     
            Construct_shelter_Q1 = int(Construct_shelter_Q1)

# To validate if user is providing the correct input format 
# Input value to be numeric and should be in [1,2,3]
            if (Construct_shelter_Q1 in lst2):  
                correct_value = True 
# If the value provided is not in the lst2 the following message will be displayed  
            else:
                print("Please provide a correct value.(e.g., 1 or 2 or 3)")              
# If the value provided is not an interger the following message will be displayed 
        except:
            print("Please provide a numeric value.")  
            
# Verifying if the given input is the right answer 
    print("\n")
    if (Construct_shelter_Q1 == 2): 
        print("""You are right! You will receive all the necessary equipments 
to construct shelter.""")
    else:
        print("""Sorry incorrect answer, You will not receive the necessary equipments 
to construct shelter.""")
        print("The right answer is option '2.Earthquake prone areas'.")        
    print("\n")

    
# Water----------------------------------------------------------------------- 
# Heads up
    print(f"""{45*"-"}WATER{44*"-"}\n""")             
    print("""Thirdly, you will have to look for water. For that you will have to 
complete a proverb.""")

# Question to earn water     
    find_water_Q1 = input(prompt= """A ---- out of water.\n>> """)
# Using lower function to convert the user input to lowercase to pass the value 
# - to the print funtion to follow proper case
    find_water_Q1 = find_water_Q1.lower()
# Printing the answer with user input    
    print(f"""Your answer is 'A {find_water_Q1} out of water.'""")
# casefold function used for caseless matching       
    find_water_Q1 = find_water_Q1.casefold()
    print("\n")
# Verifying if the given input is the right answer      
    if find_water_Q1 == "fish":
        print("You are right! You will receive a map, using that you can find the water area.")
        print("\n")
    else:
        print("Sorry incorrect answer, you will have to search for the water area on your own.")
        print(f"The right answer is 'fish'.")         
    print("\n")
    
# Food------------------------------------------------------------------------   
# Heads up
    print(f"""{45*"-"}FOOD{44*"-"}\n""")                            
    print("""Finally, you need to fetch food. For that you will have 
to answer the below question correctly.""")  
      
# Initializing value to validate if user is providing the correct input format 
# Input value to be numeric and should be in [1,2,3]
    
    lst4 = [1,2,3]
    correct_value = False
# Loop until user provides the right input format      
    while correct_value == False:
# Question to earn food
        try:
            fetch_food_q1 = input(prompt= """What is the food component present in sugar?
1.Carbohydrates
2.Fats
3.Proteins\n>> """)    
# Converting input to integer in order to validate the provided input        
            fetch_food_q1 = int(fetch_food_q1)

        
# To validate if user is providing the correct input format 
# Input value to be numeric and should be in [1,2,3]

            if (fetch_food_q1 in lst4):  
                correct_value = True 
                break
# If the value provided is not in the lst4 the following message will be displayed                 
            else:
                print("Please provide a correct value.(e.g., 1 or 2 or 3)")     
# If the value provided is not an interger the following message will be displayed              
        except:
            print("Please provide a numeric value.")
            
# Printing space    
    print("\n")    
# Verifying if the given input is the right answer     
    if (fetch_food_q1 == 1): 
        print("""You are right! You will receive a delicious meal.""")
    else:
        print("""Sorry incorrect answer, you will not be provided food, you will have 
to hunt yourself.""")  
        print("The right answer is option '1.Carbohydrates'\n")           
        print("""Great job so far, you are leveling to the next challenge which is the 
reward challenge.""")


        
#*****************************************************************************
# Stage 3-RED-band need to lookout for food, water, fire, and shelter
#*****************************************************************************
def stage3_red():
    print(f"""{45*"*"}STAGE 3-RED{40*"*"}\n""")  
    print("""You have landed in the part of the island with minimal resources 
as you belong to the red band. 
Here, you will have to lookout for food, water, fire and shelter.""")    
    print("\n")    
    
# Build fire------------------------------------------------------------------   
    print(f"""{43*"-"}BUILD FIRE{40*"-"}\n""")     
    print("""Firstly, you need to build fire to cook and for warmth.  
In order to build fire you need to answer a riddle.\n""")
    
# Question to earn fire     
    riddle = input(prompt = """I’m tall when I’m young, and I’m short when I’m old. 
What am I?\n>> """)  
# casefold function used for caseless matching       
    riddle = riddle.casefold()
    print("\n")    
# Validating user input in the list value      
    if (riddle == "candle"):
        print("""You are right! You will receive all the necessary equipments to build 
fire.""")
    else:
        print("Sorry incorrect answer, you will not be able to build fire.") 
        print(f"The right answer is 'candle'.")          
# To print space         
    print("\n")

# Construct shelter----------------------------------------------------------- 
# Heads up
    print(f"""{42*"-"}CONSTRUCT SHELTER{37*"-"}\n""")    
    print("""Secondly, you will have to construct shelter. For that you will  
have to answer the below question correctly.""")

# Initializing value to validate if user is providing the correct input format 
# Input value to be numeric and should be in [1,2,3]
    
    lst2 = [1,2,3]
    correct_value = False
# Loop until user provides the right input format      
    while correct_value == False:
# Question to earn shelter     
        try:
 
            Construct_shelter_Q1 = input(prompt= """What is the earliest form of shelter?
1.Huts
2.Caves
3.Water bodies\n>> """)  

            print("\n")
            Construct_shelter_Q1 = int(Construct_shelter_Q1)
        
# To validate if user is providing the correct input format 
# Input value to be numeric and should be in [1,2,3]
# Adding while loop to validate each question will make the code complex, hence validating
# everthing at once
            if (Construct_shelter_Q1 in lst2):  
                correct_value = True 
                break
# If the value provided is not in the lst2 the following message will be displayed                  
            else:
                print("Please provide a correct value.(e.g., 1 or 2 or 3)")   
# If the value provided is not an interger the following message will be displayed            
        except:
            print("Please provide a numeric value.")
            
# Verifying if the given input is the right answer    
            
    if (Construct_shelter_Q1 == 2): 
        print("""You are right! You will receive all the necessary equipments to construct 
shelter.""")
    else:
        print("""Sorry incorrect answer, You will not receive the necessary equipments to 
construct shelter.""")
        print("The right answer is option '2.Caves'")                  
    print("\n")

    
# Water-----------------------------------------------------------------------  
# Heads up
    print(f"""{45*"-"}WATER{44*"-"}\n""")             
    print("""Thirdly, you will have to look for water. For that you will have to complete a 
proverb.""")
    
# Question to earn water     
    find_water_Q1 = input(prompt= """Gone water does not ---- -------.\n>> """)
# Using lower function to convert the user input to lowercase to pass the value 
# - to the print funtion to follow proper case
    find_water_Q1 = find_water_Q1.lower()
# Printing the answer with user input       
    print(f"""Your answer is 'Gone water does not {find_water_Q1}.'""")
# casefold function used for caseless matching       
    find_water_Q1 = find_water_Q1.casefold()
    print("\n")    
# Verifying if the given input is the right answer     
    if (find_water_Q1 == "mill anymore"):
        print("You are right! You will receive a map, using that you can find the water area.")
        print("\n")
    else:
        print("Sorry incorrect answer, you will have to search for the water area on your own.")
        print(f"The right answer is 'mill anymore'.")          
    print("\n")

    
# Food------------------------------------------------------------------------ 
# Heads up
    print(f"""{45*"-"}FOOD{44*"-"}\n""")                            
    print("""Last part of this stage is to fetch food. For that you will have 
to answer the below question correctly.""")   
    
# Initializing value to validate if user is providing the correct input format 
# Input value to be numeric and should be in [1,2,3]
    
    lst4 = [1,2,3]
    correct_value = False
# Loop until user provides the right input format     
    while correct_value == False:
# Question to earn shelter     
        try:

            fetch_food_q1 = input(prompt= """In the drink called a zombie, what is the main 
    alcoholic ingredient?
1.Beer
2.Brandy
3.Rum\n>> """) 
            print("\n")
# Converting input to integer in order to validate the provided input              
            fetch_food_q1 = int(fetch_food_q1) 
    
# To validate if user is providing the correct input format 
# Input value to be numeric and should be in [1,2,3]
# Adding while loop to validate each question will make the code complex, hence validating
# everthing at once
            if (fetch_food_q1 in lst4):  
                correct_value = True 
                break
# If the value provided is not in the lst4 the following message will be displayed                 
            else:
                print("Please provide a correct value.(e.g., 1 or 2 or 3)")
# If the value provided is not an interger the following message will be displayed              
        except:
            print("Please provide a numeric value.")   
            
# Verifying if the given input is the right answer    
    
    if (fetch_food_q1 == 3): 
        print("""You are right! You will receive all the necessary spices to cook, but you 
will have to hunt your meet.""")
    else:
        print("""Sorry incorrect answer, you will not be provided food, you will have to 
hunt yourself.""")   
        print("The right answer is option '3.Rum'\n")            
        print("""Great job so far, you are leveling to the next challenge which is the 
reward task.""")
# will return back to the calling funtion
    return 

#*****************************************************************************
# Stage 4-Reward Task
#*****************************************************************************

def stage4():
# Heads up    
    print(f"""{45*"*"}STAGE 4{44*"*"}\n""")    
    print("Now you will be taking up the reward challenge.")
    print("You will have to answer the below question correctly to earn your reward.")
    print("\n")
        
# Allowing 2 chances for reward task in case of incorrect answer
    chances = 2
    while chances >= 1: 
# Initializing value to validate if user is providing the correct input format 
# Input value to be ['t', 'true', 'false', 'f']

        lst1=['t', 'true', 'false', 'f']  
        correct_value = False
# Loop until user provides the right input format         
        while correct_value == False:
# True/False questions to earn the reward challenge            
            reward_task_Q1 = input(prompt= "1. Mars has two kinds of motion(true/false):t/f\n>> ")                          
# To validate if user is providing the correct input format 
# casefold function used for caseless matching   
            reward_task_Q1 = reward_task_Q1.casefold()
            if (reward_task_Q1 in lst1):  
                correct_value = True 
# If the value provided is not in the lst1 the following message will be displayed             
            else:
                print("Please provide a correct value.(e.g., 't' or 'f')")               
# Validating reward challenge answer
        if (reward_task_Q1 == 't') or (reward_task_Q1 == 'true'): 
            print("""Congratulations! You have received a super power. You will skip the 
elimination round and directly make it to the finals.""")
            print("\n")
# Calling the Finale function            
            Finale()
        else: 
# All chances have been used up, but still the user did not provide the right answer             
            if chances == 1:
                print("""Sorry you lost the reward challenge again, 
you should take up the elimination task.""")
                print("The right answer is 't'")            
# This will break the current loop and go back to the main function  
# -to call the Elimination function(stage 5)
                break 
                      
            else:    
# Ask user if they would like to try one more time                
                user_option = input(prompt="""Sorry you did not win the reward challenge, 
would you like to retry once more?:y/n\n>> """)
# If 'yes' loop once more else exit and call stage 5 from the main program
                if user_option == 'y':
                    chances = chances - 1
# will continue looping            
                    continue 
                else:
                    print("The right answer is 't'")  
# will break the loop and go back to the main program  
# -to call the Elimination function(stage 5) 
                    break            
                                               


#*****************************************************************************
# Stage 5-Elimination Challenge
#*****************************************************************************

def stage5():
# Heads up on the elimination challenge
    print(f"""{45*"*"}STAGE 5{44*"*"}\n""")    
    print("Welcome to the elimination challenge.")
    print("""This round will be the most tedious one. You will have to answer all
the three math questions correctly to level up to the finale\n""")

# Initializing value to validate if user is providing the correct input format 
# Input value to be numeric and should be in [1,2,3]

    lst1 = [1,2,3]
    correct_value = False
# Loop until user provides the right input format     
    while correct_value == False:
        try:
# Questions for the elimination task    
            elimination_task_Q1 = input(prompt= """How many sides does a circle have?                                     
                                      1.Has no sides
                                      2.Has two sides 
                                      3.Has one side\n>> """)  
            elimination_task_Q2 = input(prompt= """What is the least number that is divisible by 
all the numbers from 1 to 5?
                                      1.70
                                      2.60 
                                      3.80\n>> """) 
            elimination_task_Q3 = input(prompt= """What is the mean of the data: 4, 10, 5, 9, 12?
                                      1.8
                                      2.11 
                                      3.9\n>> """)
# Converting input to integer in order to validate the provided input            
            elimination_task_Q1 = int(elimination_task_Q1)
            elimination_task_Q2 = int(elimination_task_Q2)
            elimination_task_Q3 = int(elimination_task_Q3) 

# To validate if user is providing the correct input format 
# Input value to be numeric and should be in [1,2,3]

# Understand that adding while loop to every question will provide better user experience
# However adding while loops to validate each question will make the code complex, 
# hence validating everthing at once

            if (elimination_task_Q1 in lst1) and (elimination_task_Q2 in lst1) and (elimination_task_Q3 in lst1):  
                correct_value = True 
                break
# If the value provided is not in the lst1 the following message will be displayed                 
            else:
                print("Please provide a correct value.(e.g., 1 or 2 or 3)") 
# If the value provided is not an interger the following message will be displayed             
        except:
            print("Please provide a numeric value.") 
# Verifying user's inputs    
    if (elimination_task_Q1 == 1 and elimination_task_Q2 == 2 and elimination_task_Q3 == 1): 
# Go back to the main program to call the Finale function 
        print("Congratulations! You are into the finals") 
    else: 
        print("Sorry you did not make it to the finale.")
        print(f"""The right answers are:-
Q1: 1.Has no sides
Q2: 2.60
Q3: 1.8""")     
# Call the end game function to exit the game        
        end_game() 
    return 

#*****************************************************************************
# Finale
#*****************************************************************************
def Finale():
# Heads up on the Finale    
    print(f"""{43*">"}GRAND FINALE{41*"<"}\n""")    
    print("Welcome to the 'GRAND FINALE'.")
    print("""You are one step closer to victory. You will have to answer all the
three riddles correctly to become the title winner.""")

     
# Initializing value to validate if user is providing the correct input format 
# Input value to be numeric and should be in [1,2,3]

    lst1 = [1,2,3]
    correct_value = False
# Loop until user provides the right input format     
    while correct_value == False:
        try:
# Questions for the finale     
            finale_Q1_1 = """What goes up but never comes down?  
1.Age
2.Balloon
3.Cap\n>> """
            finale_Q1_2 = """What two things can you never eat for breakfast?  
1.Fruits and yogurt
2.Lunch and dinner
3.Spinach and fish\n>> """
            finale_Q1_3 = """What has a face and two hands but no arms or legs?  
1.A clock
2.Puppet
3.A tree\n>> """        
            finale_Q2_1 = """What starts with a P, ends with an E, and has thousands 
of letters?
1.Pipe
2.Post office 
3.Page\n>> """
            finale_Q2_2 = """What tastes better than it smells?
1.A tongue
2.Durian 
3.Grapefruit\n>> """
            finale_Q2_3 = """What kind of room has no doors or windows?
1.An igloo
2.A mushroom 
3.A den\n>> """            
            finale_Q3_1 = """What has to be broken before you can use it? 
1.Bottle
2.Egg 
3.Champagne\n>> """
            finale_Q3_2 = """What sounds like a sneeze and is made out of leather?
1.A shoe
2.A coat
3.A handbag\n>> """
            finale_Q3_3 = """What grows when it eats, but dies when it drinks?
1.Human
2.Fire 
3.Air\n>> """            
            finale_rand_ques_list_Q1 = [finale_Q1_1,finale_Q1_2,finale_Q1_3]
            finale_rand_ques_list_Q2 = [finale_Q2_1,finale_Q2_2,finale_Q2_3]
            finale_rand_ques_list_Q3 = [finale_Q3_1,finale_Q3_2,finale_Q3_3]            
# Using random.choice function to randomly prompt one of the three questions for each
# - of the finale questions
            finale_rand_ques_Q1 = rand.choice(finale_rand_ques_list_Q1) 
            finale_Q1 = input(prompt= finale_rand_ques_Q1 )               
            finale_rand_ques_Q2 = rand.choice(finale_rand_ques_list_Q2) 
            finale_Q2 = input(prompt= finale_rand_ques_Q2 )  
            finale_rand_ques_Q3 = rand.choice(finale_rand_ques_list_Q3) 
            finale_Q3 = input(prompt= finale_rand_ques_Q3 )              
# Converting input to integer in order to validate the provided input   
            finale_Q1 = int(finale_Q1)
            finale_Q2 = int(finale_Q2)
            finale_Q3 = int(finale_Q3) 
# To validate if user is providing the correct input format 
# Input value to be numeric and should be in [1,2,3]

# Understand that adding while loop to every question will provide better user experience
# However adding while loops to validate each question will make the code complex, 
# hence validating everthing at once

            if (finale_Q1 in lst1) and (finale_Q2 in lst1) and (finale_Q3 in lst1):  
                correct_value = True 
# If the value provided is not in the lst1 the following message will be displayed             
            else:
                print("Please provide a correct value.(e.g., 1 or 2 or 3)")     
# If the value provided is not an interger the following message will be displayed             
        except:
            print("Please provide a numeric value.")             
# Count down 3 to reveal the results     
    print("Let's start the count down to know the results")
    count_down = 3
    while count_down > 0:
        print(count_down)
        count_down = count_down - 1
        input(prompt ="< Press ENTER to continue. >\n")
# Verifying user input        
    if ((finale_rand_ques_Q1 == finale_Q1_1 and finale_Q1 == 1) or (finale_rand_ques_Q1 == finale_Q1_2 and finale_Q1 == 2) or(finale_rand_ques_Q1 == finale_Q1_3 and finale_Q1 == 1)) and ((finale_rand_ques_Q2 == finale_Q2_1 and finale_Q2 == 2) or (finale_rand_ques_Q2 == finale_Q2_2 and finale_Q2 == 1) or(finale_rand_ques_Q2 == finale_Q2_3 and finale_Q2 == 2)) and ((finale_rand_ques_Q3 == finale_Q3_1 and finale_Q3 == 2) or (finale_rand_ques_Q3 == finale_Q3_2 and finale_Q3 == 1) or(finale_rand_ques_Q3 == finale_Q3_3 and finale_Q3 == 2)):        
# printing result in upper case using upper funtion        
        print("    you are the title winner of virtual survivor adventure text game season 1 ".upper())
        print(""" 
  ______    ______   __        ________         ______   __    __  _______   __     __  ______  __     __   ______   _______         __ 
 /      \  /      \ |  \      |        \       /      \ |  \  |  \|       \ |  \   |  \|      \|  \   |  \ /      \ |       \       |  \
|  $$$$$$\|  $$$$$$\| $$      | $$$$$$$$      |  $$$$$$\| $$  | $$| $$$$$$$\| $$   | $$ \$$$$$$| $$   | $$|  $$$$$$\| $$$$$$$\      | $$
| $$___\$$| $$  | $$| $$      | $$__          | $$___\$$| $$  | $$| $$__| $$| $$   | $$  | $$  | $$   | $$| $$  | $$| $$__| $$      | $$
 \$$    \ | $$  | $$| $$      | $$  \          \$$    \ | $$  | $$| $$    $$ \$$\ /  $$  | $$   \$$\ /  $$| $$  | $$| $$    $$      | $$
 _\$$$$$$\| $$  | $$| $$      | $$$$$          _\$$$$$$\| $$  | $$| $$$$$$$\  \$$\  $$   | $$    \$$\  $$ | $$  | $$| $$$$$$$\       \$$
|  \__| $$| $$__/ $$| $$_____ | $$_____       |  \__| $$| $$__/ $$| $$  | $$   \$$ $$   _| $$_    \$$ $$  | $$__/ $$| $$  | $$       __ 
 \$$    $$ \$$    $$| $$     \| $$     \       \$$    $$ \$$    $$| $$  | $$    \$$$   |   $$ \    \$$$    \$$    $$| $$  | $$      |  \
  \$$$$$$   \$$$$$$  \$$$$$$$$ \$$$$$$$$        \$$$$$$   \$$$$$$  \$$   \$$     \$     \$$$$$$     \$      \$$$$$$  \$$   \$$       \$$

""")
    else:  
# printing result in upper case using upper funtion          
        print("You are the runner up!".upper())
        print("""
            
$$$$$$$\  $$\   $$\ $$\   $$\ $$\   $$\ $$$$$$$$\ $$$$$$$\        $$\   $$\ $$$$$$$\  $$\ 
$$  __$$\ $$ |  $$ |$$$\  $$ |$$$\  $$ |$$  _____|$$  __$$\       $$ |  $$ |$$  __$$\ $$ |
$$ |  $$ |$$ |  $$ |$$$$\ $$ |$$$$\ $$ |$$ |      $$ |  $$ |      $$ |  $$ |$$ |  $$ |$$ |
$$$$$$$  |$$ |  $$ |$$ $$\$$ |$$ $$\$$ |$$$$$\    $$$$$$$  |      $$ |  $$ |$$$$$$$  |$$ |
$$  __$$< $$ |  $$ |$$ \$$$$ |$$ \$$$$ |$$  __|   $$  __$$<       $$ |  $$ |$$  ____/ \__|
$$ |  $$ |$$ |  $$ |$$ |\$$$ |$$ |\$$$ |$$ |      $$ |  $$ |      $$ |  $$ |$$ |          
$$ |  $$ |\$$$$$$  |$$ | \$$ |$$ | \$$ |$$$$$$$$\ $$ |  $$ |      \$$$$$$  |$$ |      $$\ 
\__|  \__| \______/ \__|  \__|\__|  \__|\________|\__|  \__|       \______/ \__|      \__|
                                                                                          
                                                                                    """)
        print("\n")
# To print the right answers based on the random question chosen    
        if finale_rand_ques_Q1 == finale_Q1_1 :
            Q1_ans ='1.Age' 
        elif finale_rand_ques_Q1 == finale_Q1_2 :
            Q1_ans ='2.Lunch and dinner' 
        else:
            Q1_ans ='1.A clock'            
        print(f"The right answer for Q1 is option {Q1_ans}.") 
            
        if finale_rand_ques_Q2 == finale_Q2_1 :
            Q2_ans ='2.Post office' 
        elif finale_rand_ques_Q2 == finale_Q2_2 :
            Q2_ans = '1.A tongue'           
        else:
            Q2_ans = '2.A mushroom'           
        print(f"The right answer for Q2 is option {Q2_ans}.")  
            
        if finale_rand_ques_Q3 == finale_Q3_1 :
            Q3_ans ='2.Egg'            
        elif finale_rand_ques_Q3 == finale_Q3_2 :
            Q3_ans ='1.A shoe'
        else:
            Q3_ans ='2.Fire'            
        print(f"The right answer for Q3 is option {Q3_ans}.")           
                                  
# calling end game function to exit the game        
    end_game()

#*****************************************************************************
# Main program - Game starts
#*****************************************************************************
# From this main function the remaning functions(various stages) are called.
def start_game():
    print("You have landed in the Mamanuca Islands of Fiji.")  
    print("You will be participating virtually in this game.\n")
# Initializing value to validate if user is providing the correct input format 
# Input value to be numeric and should be in [1,2,3]
    lst1=[1,2,3]   
    Numeric = False
    while Numeric == False:
        try:            
            contestant_emotion = input(prompt= """How do you feel to be part of the 
survivor show:
1. Happy to be part of the show.
2. Anxious about the tasks.
3. Positive that I will win the game.\n>> """) 
            contestant_emotion = int(contestant_emotion)

# To validate if user is providing the correct input format 
# Input value to be numeric and should be in [1,2,3]
            if contestant_emotion in lst1:
                Numeric = True    
            else:
                print("Please provide a correct value.(e.g., 1 or 2 or 3)")
        except:
            print("Please provide a numeric value.")      
    
    if contestant_emotion == 2:
        print("Stay motivated and do your best!")
    else:
        print("Great! Keep it that way.")
    print("\n")
        
# Calling Stage 1 function-To decide the band colour--------------------------   
    stage1()           
    
# Stage 2 and 3 will be triggered from Stage1

# Calling Stage 4 function-Reward task----------------------------------------
    print("\n")
    stage4()
    
# Calling Stage 5 function-Elimination challenge------------------------------
    print("\n")
    stage5()
    
# Calling Final stage function-Declare the Winner of the game-----------------
    print("\n")
    Finale()

# Fail function
def end_game():
    print("Thanks for playing!\n")
    play_input = False
    while play_input == False:    
        play_again = input(prompt= "Would you like to play again? y/n\n>> ")
        if (play_again == 'y'):
            play_input = True
            stage1()
        elif (play_again == 'n'):  
            play_input = True            
            sys.exit()           
        else:
            print("Invalid Input")



#*****************************************************************************
# Calling start game function to get started
start_game()
# Out:
# ************************************************************************************************
#
#                         VIRTUAL SURVIVOR ADVENTURE TEXT GAME SEASON 1
#
# ************************************************************************************************
#
# This game features contestants deliberately marooned in an isolated
# location, where they must provide food, water, fire, and shelter for themselves.
# They compete in challenges for rewards and immunity from elimination.
# They are progressively eliminated from the game based on the performance.
# This game challenges the mental abilities and the contestant who survives all the
# stages will be declared as the title winner.
#
# This game has been split into 6 stages as follow:
# 1. Contestants will be provided either 'Red' or 'Blue' band.
# 2. Based on the band contestants will be allocated to resourceful and
#    resourseless part of the island.
# ...
